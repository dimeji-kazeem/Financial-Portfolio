# %%
import json
import urllib
import requests

url = 'https://parseapi.back4app.com/classes/Continentscountriescities_Country?limit=10&keys=name,code,continent,currency'
headers = {
    'X-Parse-Application-Id': 'NUB9tbnqxWJMQECYFLcNrmECMxL1M5yND9GzCJmu', # This is your app's application id
    'X-Parse-REST-API-Key': 'x33EWxHXSOOHzOYDKqVzVO2lExvfer7oaM7Qs4qK' # This is your app's REST API key
}
data = json.loads(requests.get(url, headers=headers).content.decode('utf-8')) # Here you have the data that you need
print(json.dumps(data, indent=2))
# Out:
# {
#   "results": [
#     {
#       "objectId": "sv7fjDVISU",
#       "code": "AD",
#       "name": "Andorra",
#       "continent": {
#         "__type": "Pointer",
#         "className": "Continentscountriescities_Continent",
#         "objectId": "28HX8qDZHw"
#       },
#       "currency": "EUR",
#       "createdAt": "2019-12-09T21:04:54.350Z",
#       "updatedAt": "2020-04-13T18:18:18.830Z",
#       "languages": {
#         "__type": "Relation",
#         "className": "Continentscountriescities_Language"
#       },
#       "cities": {
#         "__type": "Relation",
#         "className": "Continentscountriescities_City"
#       },
#       "timezones": {
#         "__type": "Relation",
#         "className": "Timezone_Time_Zones_Dataset"
#       },
#       "provinces": {
#         "__type": "Relation",
#         "className": "Continentscountriescities_Subdivisions_States_Provinces"
#       }
#     },
#     {
#       "objectId": "PdgGA5Y5Tt",
#       "code": "BO",
# ...
